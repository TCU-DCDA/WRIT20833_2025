# %% [markdown]
# <a href="https://colab.research.google.com/github/TCU-DCDA/WRIT20833-2025/blob/main/notebooks/exercises/WRIT20833_InClassEx_Family_Dictionaries_F25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In-Class Exercise: "Family" Dictionaries
#
# To create an editable version, go to **File** > **Save a Copy in Drive**
#
# **General Guidelines**
#
# > Work on the following exercises in groups of 2 or 3.&nbsp;
#
# > Before you get started coding, have a short conversation to determine the person least confident in terms of their Python skills (who looks at the prompt and says "I'm not sure what they're asking me to do"?)
#
# > That person (the least confident group member) is the coder.
#
# > The rest of the group (the more confident members) "writes" the code by telling the coder what to type.&nbsp;
#
# &nbsp;

# %% [markdown]
# **Practice 1**
#
# > Create a nested dictionary named "family" that creates a key-value pair -- "name" , "age" , "profession" , "hobby" , "least favorite food" -- for at least 8 family members (or group you identify as "family").
#
# > Deliberately enter in inaccurate information or typos to two or three data points.&nbsp;
#
# &nbsp;

# %%
# Code Practice 1 here

# %% [markdown]
# **Practice 2**
#
# > Using the nested dictionary you create above, use the Change Item method from this chapter -- [https://melaniewalsh.github.io/Intro-Cultural-Analytics/02-Python/11-Dictionaries.html#change-item](https://melaniewalsh.github.io/Intro-Cultural-Analytics/02-Python/11-Dictionaries.html#change-item) to correct or update the errors you deliberately entered.
#
# &nbsp;

# %%
# Code Practice 2 here

# %% [markdown]
# **Practice 3**
#
# > Write a few lines of code that iterate in a creative way through your dictionary named "family."
#
# > For example, try applying one of the string methods listed here -- https://melaniewalsh.github.io/Intro-Cultural-Analytics/02-Python/06-String-Methods.html#id1  -- to all the string values associated with a specific key. Deliver the results in an interesting print() statement.
#
# > Or try performing a simple math operation on all the numeric values associated with a specific key. Deliver the results in an interesting print() statement that contextualizes the changes you've made.
#
# > **Bonus** if you can turn one of your creative iterations above into a properly defined and formatted **function**
#
# &nbsp;

# %%
# Code Practice 3 here
